# %%
import pandas as pd
import numpy as np

benefits_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Benefits_Cost_Sharing_PUF.csv')
#benefits_raw_df_2014.head(5)
bussiness_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Business_Rules_PUF.csv')
#bussiness_raw_df_2014.head(5)
network_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Network_PUF.csv')
#network_raw_df_2014.head(5)
plan_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Plan_Attributes_PUF_2014_2015-03-09.csv')
#plan_raw_df_2014.head(5)
rate_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Rate_PUF.csv')
#rate_raw_df_2014.head(5)
service_area_raw_df_2014 = pd.read_csv('health-insurance-marketplace/raw/2014/Service_Area_PUF.csv')
service_area_raw_df_2014.head(5)
# Out:
# /home/tanu/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (12,15,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/tanu/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (57) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        PA     22444       HIOS           9
# 1          2014        PA     22444       HIOS           9
# 2          2014        PA     22444       HIOS           9
# 3          2014        PA     22444       HIOS           9
# 4          2014        PA     22444       HIOS           9
#
#             ImportDate  IssuerId2 StateCode2 ServiceAreaId  \
# ...

# %%
benefits_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Benefits_Cost_Sharing_PUF.csv')
#benefits_raw_df_2014.head(5)
bussiness_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Business_Rules_PUF_Reformat.csv')
#bussiness_raw_df_2014.head(5)
network_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Network_PUF.csv')
#network_raw_df_2014.head(5)
plan_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Plan_Attributes_PUF.csv')
#plan_raw_df_2014.head(5)
rate_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Rate_PUF.csv')
#rate_raw_df_2014.head(5)
service_area_raw_df_2015 = pd.read_csv('health-insurance-marketplace/raw/2015/Service_Area_PUF.csv')
#service_area_raw_df_2015.head(5)
# Out:
# /home/tanu/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (33,71,72,75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
benefits_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/Benefits_Cost_Sharing_PUF_2015-12-08.csv')
#benefits_raw_df_2014.head(5)
bussiness_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/Business_Rules_PUF_2015-12-08.csv')
#bussiness_raw_df_2014.head(5)
network_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/Network_PUF_2015-12-08.csv')
#network_raw_df_2014.head(5)
plan_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/Plan_Attributes_PUF_2015-12-08.csv')
#plan_raw_df_2014.head(5)
rate_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/Rate_PUF_2015-12-08.csv')
#rate_raw_df_2014.head(5)
service_area_raw_df_2016 = pd.read_csv('health-insurance-marketplace/raw/2016/ServiceArea_PUF_2015-12-08.csv')
#service_area_raw_df_2016.head(5)
# Out:
# /home/tanu/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (31,79,80,81,85,86,87,88,89,90,135,136,137,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
benefits_raw_df_2014.head(5)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AK     21989       HIOS           6
# 1          2014        AK     21989       HIOS           6
# 2          2014        AK     21989       HIOS           6
# 3          2014        AK     21989       HIOS           6
# 4          2014        AK     21989       HIOS           6
#
#             ImportDate  IssuerId2 StateCode2 StandardComponentId  \
# 0  2014-03-19 07:06:49      21989         AK      21989AK0010001
# 1  2014-03-19 07:06:49      21989         AK      21989AK0010001
# 2  2014-03-19 07:06:49      21989         AK      21989AK0010001
# 3  2014-03-19 07:06:49      21989         AK      21989AK0010001
# 4  2014-03-19 07:06:49      21989         AK      21989AK0010001
#
#               PlanId    ...                 LimitUnit MinimumStay Exclusions  \
# 0  21989AK0010001-00    ...          Dollars per Year         NaN        NaN
# ...

# %%
benefits_attributes = list(benefits_raw_df_2014.columns.values)
benefits_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'IssuerId2',
#  'StateCode2',
#  'StandardComponentId',
#  'PlanId',
#  'BenefitName',
#  'CopayInnTier1',
#  'CopayInnTier2',
#  'CopayOutofNet',
#  'CoinsInnTier1',
#  'CoinsInnTier2',
#  'CoinsOutofNet',
#  'IsEHB',
#  'IsStateMandate',
#  'IsCovered',
#  'QuantLimitOnSvc',
#  'LimitQty',
#  'LimitUnit',
#  'MinimumStay',
#  'Exclusions',
#  'Explanation',
#  'EHBVarReason',
#  'IsSubjToDedTier1',
#  'IsSubjToDedTier2',
#  'IsExclFromInnMOOP',
#  'IsExclFromOonMOOP',
#  'RowNumber']

# %%
benefits_features = benefits_raw_df_2014
benefits_features.head(2)
removeset = ['BusinessYear','SourceName','VersionNum','ImportDate','Explanation','RowNumber']
for item in removeset:
    #print item
    benefits_features = benefits_features.drop(item, axis = 1)
    #benefits_features.head(2)
    
benefits_features.head(2)
# Out:
#   StateCode  IssuerId  IssuerId2 StateCode2 StandardComponentId  \
# 0        AK     21989      21989         AK      21989AK0010001
# 1        AK     21989      21989         AK      21989AK0010001
#
#               PlanId                      BenefitName CopayInnTier1  \
# 0  21989AK0010001-00  Routine Dental Services (Adult)     No Charge
# 1  21989AK0010001-00     Dental Check-Up for Children     No Charge
#
#   CopayInnTier2 CopayOutofNet        ...         QuantLimitOnSvc LimitQty  \
# 0           NaN     No Charge        ...                     Yes   1000.0
# 1           NaN     No Charge        ...                     Yes      1.0
#
#                LimitUnit MinimumStay Exclusions         EHBVarReason  \
# 0       Dollars per Year         NaN        NaN            Above EHB
# 1  Visit(s) per 6 Months         NaN        NaN  Substantially Equal
#
#   IsSubjToDedTier1  IsSubjToDedTier2 IsExclFromInnMOOP  IsExclFromOonMOOP
# ...

# %%
business_attributes = list(bussiness_raw_df_2014.columns.values)
business_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'IssuerId2',
#  'TIN',
#  'ProductId',
#  'StandardComponentId',
#  'EnrolleeContractRateDeterminationRule',
#  'TwoParentFamilyMaxDependentsRule',
#  'SingleParentFamilyMaxDependentsRule',
#  'DependentMaximumAgRule',
#  'ChildrenOnlyContractMaxChildrenRule',
#  'DomesticPartnerAsSpouseIndicator',
#  'SameSexPartnerAsSpouseIndicator',
#  'AgeDeterminationRule',
#  'MinimumTobaccoFreeMonthsRule',
#  'CohabitationRule',
#  'RowNumber',
#  'MarketCoverage',
#  'DentalOnly']

# %%
bussiness_features = bussiness_raw_df_2014
bussiness_features.head(2)
removeset2 = ['BusinessYear','SourceName','VersionNum','ImportDate','TIN','RowNumber']
for item in removeset2:
    #print item
    bussiness_features = bussiness_features.drop(item, axis = 1)
    #benefits_features.head(2)
    
bussiness_features.head(2)
# Out:
#   StateCode  IssuerId  IssuerId2 ProductId StandardComponentId  \
# 0        AL     82285      82285       NaN      82285AL0010006
# 1        AL     82285      82285       NaN      82285AL0020001
#
#                EnrolleeContractRateDeterminationRule  \
# 0  A different rate (specifically for parties of ...
# 1  A different rate (specifically for parties of ...
#
#   TwoParentFamilyMaxDependentsRule SingleParentFamilyMaxDependentsRule  \
# 0                        3 or more                           3 or more
# 1                        3 or more                           3 or more
#
#   DependentMaximumAgRule ChildrenOnlyContractMaxChildrenRule  \
# 0                     26                           3 or more
# 1         Not Applicable                           3 or more
#
#   DomesticPartnerAsSpouseIndicator SameSexPartnerAsSpouseIndicator  \
# 0                              Yes                             Yes
# 1                              Yes                             Yes
#
# ...

# %%
network_attributes = list(network_raw_df_2014.columns.values)
network_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'IssuerId2',
#  'StateCode2',
#  'NetworkName',
#  'NetworkId',
#  'NetworkURL',
#  'RowNumber',
#  'MarketCoverage',
#  'DentalOnly']

# %%
network_features = network_raw_df_2014
network_features.head(2)
removeset3 = ['BusinessYear','SourceName','VersionNum','ImportDate','NetworkURL','RowNumber']
for item in removeset3:
    #print item
    network_features = network_features.drop(item, axis = 1)
    #benefits_features.head(2)
    
network_features.head(2)
# Out:
#   StateCode  IssuerId  IssuerId2 StateCode2   NetworkName NetworkId  \
# 0        AK     21989      21989         AK   ODS Premier    AKN001
# 1        AK     38344      38344         AK  HeritagePlus    AKN001
#
#   MarketCoverage DentalOnly
# 0            NaN        NaN
# 1            NaN        NaN

# %%
plan_attributes = list(plan_raw_df_2014.columns.values)
plan_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'BenefitPackageId',
#  'IssuerId2',
#  'StateCode2',
#  'MarketCoverage',
#  'DentalOnlyPlan',
#  'TIN',
#  'StandardComponentId',
#  'PlanMarketingName',
#  'HIOSProductId',
#  'HPID',
#  'NetworkId',
#  'ServiceAreaId',
#  'FormularyId',
#  'IsNewPlan',
#  'PlanType',
#  'MetalLevel',
#  'UniquePlanDesign',
#  'QHPNonQHPTypeId',
#  'IsNoticeRequiredForPregnancy',
#  'IsReferralRequiredForSpecialist',
#  'SpecialistRequiringReferral',
#  'PlanLevelExclusions',
#  'IndianPlanVariationEstimatedAdvancedPaymentAmountPerEnrollee',
#  'IsHSAEligible',
#  'HSAOrHRAEmployerContribution',
#  'HSAOrHRAEmployerContributionAmount',
#  'ChildOnlyOffering',
#  'ChildOnlyPlanId',
#  'WellnessProgramOffered',
#  'DiseaseManagementProgramsOffered',
#  'EHBPediatricDentalApportionmentQuantity',
#  'EHBPercentPremiumS4',
#  'IsGuaranteedRate',
#  'SpecialtyDrugMaximumCoinsurance',
# ...

# %%
rate_attributes = list(rate_raw_df_2014.columns.values)
rate_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'IssuerId2',
#  'FederalTIN',
#  'RateEffectiveDate',
#  'RateExpirationDate',
#  'PlanId',
#  'RatingAreaId',
#  'Tobacco',
#  'Age',
#  'IndividualRate',
#  'IndividualTobaccoRate',
#  'Couple',
#  'PrimarySubscriberAndOneDependent',
#  'PrimarySubscriberAndTwoDependents',
#  'PrimarySubscriberAndThreeOrMoreDependents',
#  'CoupleAndOneDependent',
#  'CoupleAndTwoDependents',
#  'CoupleAndThreeOrMoreDependents',
#  'RowNumber']

# %%
rate_features = rate_raw_df_2014
rate_features.head(2)
removeset4 = ['BusinessYear','SourceName','VersionNum','FederalTIN','ImportDate','RowNumber']
for item in removeset4:
    #print item
    rate_features = rate_features.drop(item, axis = 1)
    #benefits_features.head(2)
    
rate_features.head(2)
# Out:
#   StateCode  IssuerId  IssuerId2 RateEffectiveDate RateExpirationDate  \
# 0        AK     21989      21989        2014-01-01         2014-12-31
# 1        AK     21989      21989        2014-01-01         2014-12-31
#
#            PlanId   RatingAreaId        Tobacco            Age  \
# 0  21989AK0010001  Rating Area 1  No Preference           0-20
# 1  21989AK0020001  Rating Area 1  No Preference  Family Option
#
#    IndividualRate  IndividualTobaccoRate  Couple  \
# 0           29.00                    NaN     NaN
# 1           36.95                    NaN    73.9
#
#    PrimarySubscriberAndOneDependent  PrimarySubscriberAndTwoDependents  \
# 0                               NaN                                NaN
# 1                            107.61                             107.61
#
#    PrimarySubscriberAndThreeOrMoreDependents  CoupleAndOneDependent  \
# 0                                        NaN                    NaN
# ...

# %%
service_attributes = list(service_area_raw_df_2014.columns.values)
service_attributes
# Out:
# ['BusinessYear',
#  'StateCode',
#  'IssuerId',
#  'SourceName',
#  'VersionNum',
#  'ImportDate',
#  'IssuerId2',
#  'StateCode2',
#  'ServiceAreaId',
#  'ServiceAreaName',
#  'CoverEntireState',
#  'County',
#  'PartialCounty',
#  'ZipCodes',
#  'PartialCountyJustification',
#  'RowNumber',
#  'MarketCoverage',
#  'DentalOnly']

# %%
service_features = service_area_raw_df_2014
service_features.head(2)
removeset5 = ['BusinessYear','SourceName','VersionNum','ImportDate','RowNumber']
for item in removeset5:
    #print item
    service_features = service_features.drop(item, axis = 1)
    #benefits_features.head(2)
    
service_features.head(2)
# Out:
#   StateCode  IssuerId  IssuerId2 StateCode2 ServiceAreaId  \
# 0        PA     22444      22444         PA        PAS001
# 1        PA     22444      22444         PA        PAS001
#
#          ServiceAreaName CoverEntireState   County PartialCounty ZipCodes  \
# 0  Geisinger Health Plan               No  42103.0            No      NaN
# 1  Geisinger Health Plan               No  42105.0            No      NaN
#
#   PartialCountyJustification MarketCoverage DentalOnly
# 0                        NaN            NaN        NaN
# 1                        NaN            NaN        NaN

# %%
from matplotlib import pyplot as plt
# %matplotlib inline 
benefits_features.corr(method = 'kendall')
# Out:
#              IssuerId  IssuerId2  LimitQty  MinimumStay
# IssuerId     1.000000   1.000000 -0.000097          NaN
# IssuerId2    1.000000   1.000000 -0.000097          NaN
# LimitQty    -0.000097  -0.000097  1.000000          NaN
# MinimumStay       NaN        NaN       NaN          1.0

# %%
benefits_features = benefits_features.drop('IssuerId', axis = 1)

# %%
plt.matshow(benefits_features.corr(method = 'kendall'))
